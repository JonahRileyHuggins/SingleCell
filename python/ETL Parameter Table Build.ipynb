# %% [markdown]
# # ETL: Converting Parameters in Ratelaw file to standalone Table
#
# Parameters in the Ratelaws file are mishandled and because of invalid table structures (according to Relational Table Normalization Rules), we have to use a REGEX parsing mechanism to find and set-values for parameters.
#
# To alleviate these issues, placing parameters, bound to a reaction Id, in PEtab format, would greatly alleviate this issue.

# %% [markdown]
# ### First: Package import and file loading

# %%
import os
import re
import pandas as pd

ratelaws_df = pd.read_csv('../data/Ratelaws_updated_names.tsv', sep='\t', header=0)

# %% [markdown]
# ### Second: Construct New Table By Index Scanning Ratelaws table, update params_table
#
# Formatted with PEtab V1 headers.

# %%
params_table = pd.DataFrame()

for i, row in ratelaws_df.iterrows():

    reactionId = row.iloc[0]
    
    paramids = [f'parameter{i}' for i in range(1, 9)]

    # Only get parameter names that are not NaN
    valid_params = [p for p in paramids if pd.notna(row[p])]

    try: 
        float(row.loc['ratelaw'])
        
        new_param_name = "k" + str(reactionId)[1:] + '_' + str(1)
        value = row.loc['ratelaw']
        new_params_row = {
        'reactionId': str(reactionId), 
        'parameterId': new_param_name, 
        'parameterScale': 'lin', 
        'lowerBound': float(value), 
        'upperBound': float(value), 
        'nominalValue': float(value), 
        'estimate': int(0)
        }

        params_table = pd.concat([params_table, pd.DataFrame([new_params_row])])
        continue

    except:
        for j, column_name in enumerate(valid_params):
        
            # All SPARCED reactions are labeled with 'v' as the initial character, removed via [1:]
            new_param_name = "k" + str(reactionId)[1:] + '_' + str(j+1)

            value = row[column_name]
            
            new_params_row = {
            'reactionId': str(reactionId), 
            'parameterId': new_param_name, 
            'parameterScale': 'lin', 
            'lowerBound': float(value), 
            'upperBound': float(value), 
            'nominalValue': float(value), 
            'estimate': int(0)
            }

            params_table = pd.concat([params_table, pd.DataFrame([new_params_row])])

# %%
params_table
# Out:
#    reactionId parameterId parameterScale  lowerBound  upperBound  \
# 0         vbR       kbR_1            lin    0.004200    0.004200
# 0         vbR       kbR_2            lin    0.040000    0.040000
# 0         vbR       kbR_3            lin    5.000000    5.000000
# 0         vbR       kbR_4            lin    4.860000    4.860000
# 0         vdR       kdR_1            lin    0.000002    0.000002
# ..        ...         ...            ...         ...         ...
# 0     vTCd145   kTCd145_1            lin    0.000074    0.000074
# 0     vTCd146   kTCd146_1            lin    0.000074    0.000074
# 0     vTCd147   kTCd147_1            lin    0.000074    0.000074
# 0     vTCd148   kTCd148_1            lin    0.000074    0.000074
# 0     vTCd149   kTCd149_1            lin    0.005000    0.005000
#
#     nominalValue  estimate
# 0       0.004200         0
# 0       0.040000         0
# 0       5.000000         0
# 0       4.860000         0
# 0       0.000002         0
# ..           ...       ...
# 0       0.000074         0
# 0       0.000074         0
# 0       0.000074         0
# 0       0.000074         0
# 0       0.005000         0
#
# [3516 rows x 7 columns]

# %% [markdown]
# ### Third: Inspect for duplicates and formatting errors:

# %%
params_table.drop_duplicates()
# Out:
#    reactionId parameterId parameterScale  lowerBound  upperBound  \
# 0         vbR       kbR_1            lin    0.004200    0.004200
# 0         vbR       kbR_2            lin    0.040000    0.040000
# 0         vbR       kbR_3            lin    5.000000    5.000000
# 0         vbR       kbR_4            lin    4.860000    4.860000
# 0         vdR       kdR_1            lin    0.000002    0.000002
# ..        ...         ...            ...         ...         ...
# 0     vTCd145   kTCd145_1            lin    0.000074    0.000074
# 0     vTCd146   kTCd146_1            lin    0.000074    0.000074
# 0     vTCd147   kTCd147_1            lin    0.000074    0.000074
# 0     vTCd148   kTCd148_1            lin    0.000074    0.000074
# 0     vTCd149   kTCd149_1            lin    0.005000    0.005000
#
#     nominalValue  estimate
# 0       0.004200         0
# 0       0.040000         0
# 0       5.000000         0
# 0       4.860000         0
# 0       0.000002         0
# ..           ...       ...
# 0       0.000074         0
# 0       0.000074         0
# 0       0.000074         0
# 0       0.000074         0
# 0       0.005000         0
#
# [3516 rows x 7 columns]

# %% [markdown]
# ### Fourth: Save to new file

# %%
params_table.to_csv('../data/Parameters.tsv', index=False, sep='\t')

# %% [markdown]
# ### Fifth: Remove parameters columns from Ratelaws and save

# %%
ratelaws_df = ratelaws_df.drop(columns=['parameter1', 'parameter2', 'parameter3', 'parameter4',
                                        'parameter5', 'parameter6', 'parameter7', 'parameter8'])

# %% [markdown]
# ### Sixth: Add ratelaws for first order reactions:

# %%
for i, row in ratelaws_df.iterrows():

    reactionId = row.iloc[0]
    # print('reactionId: ', reactionId)

    ratelaw = row.loc['ratelaw']

    try: 
        
        rand_var = float(ratelaw)
            
        # print('ratelaw is pure float:', ratelaw)

        formula = "k" + str(reactionId)[1:] + '_' + str(1)

        rxn = row.get('r ; p', '')

        # print('Reaction Parts: ', rxn)

        reactants_str, products_str = (rxn.split(';') + [''])[:2]

        reactants = [r.strip() for r in reactants_str.split('+') if r.strip()]

        products = [p.strip() for p in products_str.split('+') if p.strip()]

        if reactants != []:
            for reactant in reactants:
                formula = formula + str(f'*{reactant}')

        ratelaws_df.at[i, 'ratelaw'] = formula

    except ValueError:
        # print('cell has string formula:', ratelaw)
        continue
# Out:
# reactionId                         vdR
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p              cyt_imp_Ribosome_ ;
# ratelaw        kdR_1*cyt_imp_Ribosome_
# Name: 1, dtype: object
# reactionId                        vTLCd1
# solver                     Deterministic
# compartment                      Nucleus
# r ; p                 nuc_prot_i_TP53_ ;
# ratelaw        kTLCd1_1*nuc_prot_i_TP53_
# Name: 143, dtype: object
# reactionId                      vTLCd2
# solver                   Deterministic
# compartment                    Nucleus
# r ; p                 nuc_prot_MDM2_ ;
# ratelaw        kTLCd2_1*nuc_prot_MDM2_
# Name: 144, dtype: object
# reactionId                       vTLCd3
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                 nuc_prot_PPM1D_ ;
# ratelaw        kTLCd3_1*nuc_prot_PPM1D_
# Name: 145, dtype: object
# reactionId                       vTLCd4
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                 nuc_prot_BRCA2_ ;
# ratelaw        kTLCd4_1*nuc_prot_BRCA2_
# Name: 146, dtype: object
# reactionId                      vTLCd5
# solver                   Deterministic
# compartment                    Nucleus
# r ; p                 nuc_prot_MSH6_ ;
# ratelaw        kTLCd5_1*nuc_prot_MSH6_
# Name: 147, dtype: object
# reactionId                      vTLCd6
# solver                   Deterministic
# compartment                    Nucleus
# r ; p                 nuc_prot_MGMT_ ;
# ratelaw        kTLCd6_1*nuc_prot_MGMT_
# Name: 148, dtype: object
# reactionId                        vTLCd7
# solver                     Deterministic
# compartment                      Nucleus
# r ; p                 nuc_prot_CDKN2A_ ;
# ratelaw        kTLCd7_1*nuc_prot_CDKN2A_
# Name: 149, dtype: object
# reactionId                      vTLCd8
# solver                   Deterministic
# compartment                    Nucleus
# r ; p                 nuc_prot_MDM4_ ;
# ratelaw        kTLCd8_1*nuc_prot_MDM4_
# Name: 150, dtype: object
# reactionId                       vTLCd9
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                 nuc_prot_i_ATM_ ;
# ratelaw        kTLCd9_1*nuc_prot_i_ATM_
# Name: 151, dtype: object
# reactionId                       vTLCd10
# solver                     Deterministic
# compartment                      Nucleus
# r ; p                  nuc_prot_i_ATR_ ;
# ratelaw        kTLCd10_1*nuc_prot_i_ATR_
# Name: 152, dtype: object
# reactionId                     vTLCd11
# solver                   Deterministic
# compartment                    Nucleus
# r ; p                  nuc_prot_RB1_ ;
# ratelaw        kTLCd11_1*nuc_prot_RB1_
# Name: 153, dtype: object
# reactionId                     vTLCd12
# solver                   Deterministic
# compartment                    Nucleus
# r ; p                  nuc_prot_E2F_ ;
# ratelaw        kTLCd12_1*nuc_prot_E2F_
# Name: 154, dtype: object
# reactionId                      vTLCd13
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                  nuc_prot_CCND_ ;
# ratelaw        kTLCd13_1*nuc_prot_CCND_
# Name: 155, dtype: object
# reactionId                      vTLCd14
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                  nuc_prot_CCNE_ ;
# ratelaw        kTLCd14_1*nuc_prot_CCNE_
# Name: 156, dtype: object
# reactionId                      vTLCd15
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                  nuc_prot_SKP2_ ;
# ratelaw        kTLCd15_1*nuc_prot_SKP2_
# Name: 157, dtype: object
# reactionId                                      vTLCd16
# solver                                    Deterministic
# compartment                                     Nucleus
# r ; p                  nuc_prot_i_CDC25B__CCNA__CDK2_ ;
# ratelaw        kTLCd16_1*nuc_prot_i_CDC25B__CCNA__CDK2_
# Name: 158, dtype: object
# reactionId                                      vTLCd17
# solver                                    Deterministic
# compartment                                     Nucleus
# r ; p                  nuc_prot_i_CDC25A__CCNE__CDK2_ ;
# ratelaw        kTLCd17_1*nuc_prot_i_CDC25A__CCNE__CDK2_
# Name: 159, dtype: object
# reactionId                                      vTLCd18
# solver                                    Deterministic
# compartment                                     Nucleus
# r ; p                  nuc_prot_i_CDC25C__CCNB__CDK1_ ;
# ratelaw        kTLCd18_1*nuc_prot_i_CDC25C__CCNB__CDK1_
# Name: 160, dtype: object
# reactionId                      vTLCd19
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                  nuc_prot_CCNA_ ;
# ratelaw        kTLCd19_1*nuc_prot_CCNA_
# Name: 161, dtype: object
# reactionId                        vTLCd20
# solver                      Deterministic
# compartment                       Nucleus
# r ; p                  nuc_prot_CDKN1B_ ;
# ratelaw        kTLCd20_1*nuc_prot_CDKN1B_
# Name: 162, dtype: object
# reactionId                        vTLCd21
# solver                      Deterministic
# compartment                       Nucleus
# r ; p                  nuc_prot_a_CDH1_ ;
# ratelaw        kTLCd21_1*nuc_prot_a_CDH1_
# Name: 163, dtype: object
# reactionId                      vTLCd22
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                  nuc_prot_CCNB_ ;
# ratelaw        kTLCd22_1*nuc_prot_CCNB_
# Name: 164, dtype: object
# reactionId                         vTLCd23
# solver                       Deterministic
# compartment                        Nucleus
# r ; p                  nuc_prot_i_CDC20_ ;
# ratelaw        kTLCd23_1*nuc_prot_i_CDC20_
# Name: 165, dtype: object
# reactionId                      vTLCd24
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                  nuc_prot_WEE1_ ;
# ratelaw        kTLCd24_1*nuc_prot_WEE1_
# Name: 166, dtype: object
# reactionId                       vTLCd25
# solver                     Deterministic
# compartment                      Nucleus
# r ; p                  nuc_prot_CHEK1_ ;
# ratelaw        kTLCd25_1*nuc_prot_CHEK1_
# Name: 167, dtype: object
# reactionId                        vTLCd26
# solver                      Deterministic
# compartment                       Nucleus
# r ; p                  nuc_prot_CDKN1A_ ;
# ratelaw        kTLCd26_1*nuc_prot_CDKN1A_
# Name: 168, dtype: object
# reactionId                         vTLCd27
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  ext_prot_TNFSF10_ ;
# ratelaw        kTLCd27_1*ext_prot_TNFSF10_
# Name: 169, dtype: object
# reactionId                          vTLCd28
# solver                        Deterministic
# compartment                       Cytoplasm
# r ; p                  cyt_prot_TNFRSF10_ ;
# ratelaw        kTLCd28_1*cyt_prot_TNFRSF10_
# Name: 170, dtype: object
# reactionId                       vTLCd29
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_CFLAR_ ;
# ratelaw        kTLCd29_1*cyt_prot_CFLAR_
# Name: 171, dtype: object
# reactionId                         vTLCd30
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_p_CASP8_ ;
# ratelaw        kTLCd30_1*cyt_prot_p_CASP8_
# Name: 172, dtype: object
# reactionId                      vTLCd31
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_BFAR_ ;
# ratelaw        kTLCd31_1*cyt_prot_BFAR_
# Name: 173, dtype: object
# reactionId                         vTLCd32
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_p_CASP3_ ;
# ratelaw        kTLCd32_1*cyt_prot_p_CASP3_
# Name: 174, dtype: object
# reactionId                         vTLCd33
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_p_CASP6_ ;
# ratelaw        kTLCd33_1*cyt_prot_p_CASP6_
# Name: 175, dtype: object
# reactionId                      vTLCd34
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_XIAP_ ;
# ratelaw        kTLCd34_1*cyt_prot_XIAP_
# Name: 176, dtype: object
# reactionId                       vTLCd35
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_PARP1_ ;
# ratelaw        kTLCd35_1*cyt_prot_PARP1_
# Name: 177, dtype: object
# reactionId                     vTLCd36
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_BID_ ;
# ratelaw        kTLCd36_1*cyt_prot_BID_
# Name: 178, dtype: object
# reactionId                      vTLCd37
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_BCL2_ ;
# ratelaw        kTLCd37_1*cyt_prot_BCL2_
# Name: 179, dtype: object
# reactionId                       vTLCd38
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_i_BAX_ ;
# ratelaw        kTLCd38_1*cyt_prot_i_BAX_
# Name: 180, dtype: object
# reactionId                                 vTLCd39
# solver                               Deterministic
# compartment                           Mitochondria
# r ; p                  mit_mixed_CYC1__Membrane_ ;
# ratelaw        kTLCd39_1*mit_mixed_CYC1__Membrane_
# Name: 181, dtype: object
# reactionId                                   vTLCd40
# solver                                 Deterministic
# compartment                             Mitochondria
# r ; p                  mit_mixed_DIABLO__Membrane_ ;
# ratelaw        kTLCd40_1*mit_mixed_DIABLO__Membrane_
# Name: 182, dtype: object
# reactionId                         vTLCd41
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_i_APAF1_ ;
# ratelaw        kTLCd41_1*cyt_prot_i_APAF1_
# Name: 183, dtype: object
# reactionId                         vTLCd42
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_i_PCSK9_ ;
# ratelaw        kTLCd42_1*cyt_prot_i_PCSK9_
# Name: 184, dtype: object
# reactionId                     vTLCd43
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_BAD_ ;
# ratelaw        kTLCd43_1*cyt_prot_BAD_
# Name: 185, dtype: object
# reactionId                      vTLCd44
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_BBC3_ ;
# ratelaw        kTLCd44_1*cyt_prot_BBC3_
# Name: 186, dtype: object
# reactionId                        vTLCd45
# solver                      Deterministic
# compartment                     Cytoplasm
# r ; p                  cyt_prot_PMAIP1_ ;
# ratelaw        kTLCd45_1*cyt_prot_PMAIP1_
# Name: 187, dtype: object
# reactionId                         vTLCd46
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_BCL2L11_ ;
# ratelaw        kTLCd46_1*cyt_prot_BCL2L11_
# Name: 188, dtype: object
# reactionId                     vTLCd47
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  ext_prot_EGF_ ;
# ratelaw        kTLCd47_1*ext_prot_EGF_
# Name: 189, dtype: object
# reactionId                      vTLCd48
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  ext_prot_NRG1_ ;
# ratelaw        kTLCd48_1*ext_prot_NRG1_
# Name: 190, dtype: object
# reactionId                     vTLCd49
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  ext_prot_HGF_ ;
# ratelaw        kTLCd49_1*ext_prot_HGF_
# Name: 191, dtype: object
# reactionId                       vTLCd50
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  ext_prot_PDGFB_ ;
# ratelaw        kTLCd50_1*ext_prot_PDGFB_
# Name: 192, dtype: object
# reactionId                     vTLCd51
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  ext_prot_FGF_ ;
# ratelaw        kTLCd51_1*ext_prot_FGF_
# Name: 193, dtype: object
# reactionId                     vTLCd52
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  ext_prot_IGF_ ;
# ratelaw        kTLCd52_1*ext_prot_IGF_
# Name: 194, dtype: object
# reactionId                     vTLCd53
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  ext_prot_INS_ ;
# ratelaw        kTLCd53_1*ext_prot_INS_
# Name: 195, dtype: object
# reactionId                      vTLCd54
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_EGFR_ ;
# ratelaw        kTLCd54_1*cyt_prot_EGFR_
# Name: 196, dtype: object
# reactionId                       vTLCd55
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_ERBB2_ ;
# ratelaw        kTLCd55_1*cyt_prot_ERBB2_
# Name: 197, dtype: object
# reactionId                       vTLCd56
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_ERBB3_ ;
# ratelaw        kTLCd56_1*cyt_prot_ERBB3_
# Name: 198, dtype: object
# reactionId                       vTLCd57
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_ERBB4_ ;
# ratelaw        kTLCd57_1*cyt_prot_ERBB4_
# Name: 199, dtype: object
# reactionId                          vTLCd58
# solver                        Deterministic
# compartment                       Cytoplasm
# r ; p                  cyt_prot_EGFRvIII_ ;
# ratelaw        kTLCd58_1*cyt_prot_EGFRvIII_
# Name: 200, dtype: object
# reactionId                     vTLCd59
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_MET_ ;
# ratelaw        kTLCd59_1*cyt_prot_MET_
# Name: 201, dtype: object
# reactionId                        vTLCd60
# solver                      Deterministic
# compartment                     Cytoplasm
# r ; p                  cyt_prot_PDGFRB_ ;
# ratelaw        kTLCd60_1*cyt_prot_PDGFRB_
# Name: 202, dtype: object
# reactionId                      vTLCd61
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_FGFR_ ;
# ratelaw        kTLCd61_1*cyt_prot_FGFR_
# Name: 203, dtype: object
# reactionId                       vTLCd62
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_IGF1R_ ;
# ratelaw        kTLCd62_1*cyt_prot_IGF1R_
# Name: 204, dtype: object
# reactionId                      vTLCd63
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_INSR_ ;
# ratelaw        kTLCd63_1*cyt_prot_INSR_
# Name: 205, dtype: object
# reactionId                     vTLCd64
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_IRS_ ;
# ratelaw        kTLCd64_1*cyt_prot_IRS_
# Name: 206, dtype: object
# reactionId                       vTLCd65
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_SPRY2_ ;
# ratelaw        kTLCd65_1*cyt_prot_SPRY2_
# Name: 207, dtype: object
# reactionId                     vTLCd66
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_CBL_ ;
# ratelaw        kTLCd66_1*cyt_prot_CBL_
# Name: 208, dtype: object
# reactionId                      vTLCd67
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_GRB2_ ;
# ratelaw        kTLCd67_1*cyt_prot_GRB2_
# Name: 209, dtype: object
# reactionId                      vTLCd68
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_PLCG_ ;
# ratelaw        kTLCd68_1*cyt_prot_PLCG_
# Name: 210, dtype: object
# reactionId                       vTLCd69
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_PI3KC_ ;
# ratelaw        kTLCd69_1*cyt_prot_PI3KC_
# Name: 211, dtype: object
# reactionId                       vTLCd70
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_PI3KR_ ;
# ratelaw        kTLCd70_1*cyt_prot_PI3KR_
# Name: 212, dtype: object
# reactionId                         vTLCd71
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_PIK3C2A_ ;
# ratelaw        kTLCd71_1*cyt_prot_PIK3C2A_
# Name: 213, dtype: object
# reactionId                     vTLCd72
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_GRP_ ;
# ratelaw        kTLCd72_1*cyt_prot_GRP_
# Name: 214, dtype: object
# reactionId                           vTLCd73
# solver                         Deterministic
# compartment                        Cytoplasm
# r ; p                  cyt_mixed_RAS__GDP_ ;
# ratelaw        kTLCd73_1*cyt_mixed_RAS__GDP_
# Name: 215, dtype: object
# reactionId                     vTLCd74
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_NF1_ ;
# ratelaw        kTLCd74_1*cyt_prot_NF1_
# Name: 216, dtype: object
# reactionId                      vTLCd75
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_RAF1_ ;
# ratelaw        kTLCd75_1*cyt_prot_RAF1_
# Name: 217, dtype: object
# reactionId                      vTLCd76
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_BRAF_ ;
# ratelaw        kTLCd76_1*cyt_prot_BRAF_
# Name: 218, dtype: object
# reactionId                       vTLCd77
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_MAP2K_ ;
# ratelaw        kTLCd77_1*cyt_prot_MAP2K_
# Name: 219, dtype: object
# reactionId                       vTLCd78
# solver                     Deterministic
# compartment                      Nucleus
# r ; p                  cyt_prot_DUSP6_ ;
# ratelaw        kTLCd78_1*cyt_prot_DUSP6_
# Name: 220, dtype: object
# reactionId                        vTLCd79
# solver                      Deterministic
# compartment                       Nucleus
# r ; p                  cyt_prot_RPS6KA_ ;
# ratelaw        kTLCd79_1*cyt_prot_RPS6KA_
# Name: 221, dtype: object
# reactionId                       vTLCd80
# solver                     Deterministic
# compartment                      Nucleus
# r ; p                  nuc_prot_DUSP1_ ;
# ratelaw        kTLCd80_1*nuc_prot_DUSP1_
# Name: 222, dtype: object
# reactionId                     vTLCd81
# solver                   Deterministic
# compartment                    Nucleus
# r ; p                  nuc_prot_FOS_ ;
# ratelaw        kTLCd81_1*nuc_prot_FOS_
# Name: 223, dtype: object
# reactionId                     vTLCd82
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  nuc_prot_JUN_ ;
# ratelaw        kTLCd82_1*nuc_prot_JUN_
# Name: 224, dtype: object
# reactionId                     vTLCd83
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  nuc_prot_MYC_ ;
# ratelaw        kTLCd83_1*nuc_prot_MYC_
# Name: 225, dtype: object
# reactionId                        vTLCd84
# solver                      Deterministic
# compartment                     Cytoplasm
# r ; p                  cyt_prot_CTNNB1_ ;
# ratelaw        kTLCd84_1*cyt_prot_CTNNB1_
# Name: 226, dtype: object
# reactionId                      vTLCd85
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_PTEN_ ;
# ratelaw        kTLCd85_1*cyt_prot_PTEN_
# Name: 227, dtype: object
# reactionId                     vTLCd86
# solver                   Deterministic
# compartment                  Cytoplasm
# r ; p                  cyt_prot_AKT_ ;
# ratelaw        kTLCd86_1*cyt_prot_AKT_
# Name: 228, dtype: object
# reactionId                       vTLCd87
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_PDPK1_ ;
# ratelaw        kTLCd87_1*cyt_prot_PDPK1_
# Name: 229, dtype: object
# reactionId                        vTLCd88
# solver                      Deterministic
# compartment                     Cytoplasm
# r ; p                  cyt_prot_RICTOR_ ;
# ratelaw        kTLCd88_1*cyt_prot_RICTOR_
# Name: 230, dtype: object
# reactionId                      vTLCd89
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_MTOR_ ;
# ratelaw        kTLCd89_1*cyt_prot_MTOR_
# Name: 231, dtype: object
# reactionId                       vTLCd90
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_GSK3B_ ;
# ratelaw        kTLCd90_1*cyt_prot_GSK3B_
# Name: 232, dtype: object
# reactionId                      vTLCd91
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_TSC1_ ;
# ratelaw        kTLCd91_1*cyt_prot_TSC1_
# Name: 233, dtype: object
# reactionId                      vTLCd92
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_TSC2_ ;
# ratelaw        kTLCd92_1*cyt_prot_TSC2_
# Name: 234, dtype: object
# reactionId                      vTLCd93
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_PRKC_ ;
# ratelaw        kTLCd93_1*cyt_prot_PRKC_
# Name: 235, dtype: object
# reactionId                       vTLCd94
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_PEBP1_ ;
# ratelaw        kTLCd94_1*cyt_prot_PEBP1_
# Name: 236, dtype: object
# reactionId                      vTLCd95
# solver                    Deterministic
# compartment                   Cytoplasm
# r ; p                  cyt_prot_MAPK_ ;
# ratelaw        kTLCd95_1*cyt_prot_MAPK_
# Name: 237, dtype: object
# reactionId                       vTLCd96
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_FOXO3_ ;
# ratelaw        kTLCd96_1*cyt_prot_FOXO3_
# Name: 238, dtype: object
# reactionId                            vTLCd97
# solver                          Deterministic
# compartment                         Cytoplasm
# r ; p                  cyt_mixed_RHEB__GDP_ ;
# ratelaw        kTLCd97_1*cyt_mixed_RHEB__GDP_
# Name: 239, dtype: object
# reactionId                       vTLCd98
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                  cyt_prot_RPTOR_ ;
# ratelaw        kTLCd98_1*cyt_prot_RPTOR_
# Name: 240, dtype: object
# reactionId                         vTLCd99
# solver                       Deterministic
# compartment                      Cytoplasm
# r ; p                  cyt_prot_RPS6KB1_ ;
# ratelaw        kTLCd99_1*cyt_prot_RPS6KB1_
# Name: 241, dtype: object
# reactionId                          vTLCd100
# solver                         Deterministic
# compartment                        Cytoplasm
# r ; p                   cyt_prot_EIF4EBP1_ ;
# ratelaw        kTLCd100_1*cyt_prot_EIF4EBP1_
# Name: 242, dtype: object
# reactionId                      vTLCd101
# solver                     Deterministic
# compartment                    Cytoplasm
# r ; p                   cyt_prot_SOS1_ ;
# ratelaw        kTLCd101_1*cyt_prot_SOS1_
# Name: 243, dtype: object
# reactionId                       vTLCd102
# solver                      Deterministic
# compartment                     Cytoplasm
# r ; p                   cyt_prot_EIF4E_ ;
# ratelaw        kTLCd102_1*cyt_prot_EIF4E_
# Name: 244, dtype: object
# reactionId                                                   vE1
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_EIF4E_ + cyt_mrna_TOTAL ; cyt_mixed_E...
# ratelaw                     kE1_1*cyt_prot_EIF4E_*cyt_mrna_TOTAL
# Name: 245, dtype: object
# reactionId                                                   vE2
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_mixed_EIF4E__mrna_TOTAL ; cyt_prot_EIF4E_ ...
# ratelaw                        kE2_1*cyt_mixed_EIF4E__mrna_TOTAL
# Name: 246, dtype: object
# reactionId                  vE3
# solver            Deterministic
# compartment           Cytoplasm
# r ; p          ; cyt_mrna_TOTAL
# ratelaw                   kE3_1
# Name: 247, dtype: object
# reactionId                      vE4
# solver                Deterministic
# compartment               Cytoplasm
# r ; p              cyt_mrna_TOTAL ;
# ratelaw        kE4_1*cyt_mrna_TOTAL
# Name: 248, dtype: object
# reactionId                                   vE5
# solver                             Deterministic
# compartment                            Cytoplasm
# r ; p              cyt_mixed_EIF4E__mrna_TOTAL ;
# ratelaw        kE5_1*cyt_mixed_EIF4E__mrna_TOTAL
# Name: 249, dtype: object
# reactionId                    vD1
# solver              Deterministic
# compartment               Nucleus
# r ; p          ; nuc_prot_i_TP53_
# ratelaw                     kD1_1
# Name: 250, dtype: object
# reactionId                        vD5
# solver                  Deterministic
# compartment                   Nucleus
# r ; p              nuc_prot_i_TP53_ ;
# ratelaw        kD5_1*nuc_prot_i_TP53_
# Name: 254, dtype: object
# reactionId                  vD7
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_MDM2_
# ratelaw                   kD7_1
# Name: 256, dtype: object
# reactionId                  vD8
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_MDM2_
# ratelaw                   kD8_1
# Name: 257, dtype: object
# reactionId                      vD11
# solver                 Deterministic
# compartment                  Nucleus
# r ; p               nuc_prot_MDM2_ ;
# ratelaw        kD11_1*nuc_prot_MDM2_
# Name: 260, dtype: object
# reactionId                  vD12
# solver             Deterministic
# compartment              Nucleus
# r ; p          ; nuc_prot_PPM1D_
# ratelaw                   kD12_1
# Name: 261, dtype: object
# reactionId                       vD13
# solver                  Deterministic
# compartment                   Nucleus
# r ; p               nuc_prot_PPM1D_ ;
# ratelaw        kD13_1*nuc_prot_PPM1D_
# Name: 262, dtype: object
# reactionId                       vD16
# solver                  Deterministic
# compartment                   Nucleus
# r ; p               nuc_prot_p_ATM_ ;
# ratelaw        kD16_1*nuc_prot_p_ATM_
# Name: 265, dtype: object
# reactionId                       vD18
# solver                  Deterministic
# compartment                   Nucleus
# r ; p               nuc_prot_a_ATR_ ;
# ratelaw        kD18_1*nuc_prot_a_ATR_
# Name: 267, dtype: object
# reactionId                                                  vD62
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_a_TP53__MDM4_ ; nuc_prot_a_TP53_ + nu...
# ratelaw                            kD62_1*nuc_prot_a_TP53__MDM4_
# Name: 311, dtype: object
# reactionId                 vC1
# solver           Deterministic
# compartment            Nucleus
# r ; p          ; nuc_prot_RB1_
# ratelaw                  kC1_1
# Name: 316, dtype: object
# reactionId                                                   vC2
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_RB1_ + nuc_prot_E2F_ ; nuc_prot_RB1__...
# ratelaw                        kC2_1*nuc_prot_RB1_*nuc_prot_E2F_
# Name: 317, dtype: object
# reactionId                                                   vC3
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_RB1__E2F_ ; nuc_prot_RB1_ + nuc_prot_...
# ratelaw                                 kC3_1*nuc_prot_RB1__E2F_
# Name: 318, dtype: object
# reactionId                     vC6
# solver               Deterministic
# compartment                Nucleus
# r ; p              nuc_prot_RB1_ ;
# ratelaw        kC6_1*nuc_prot_RB1_
# Name: 321, dtype: object
# reactionId                                                   vC9
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_p_RB1_ + nuc_prot_E2F_ ; nuc_prot_p_R...
# ratelaw                      kC9_1*nuc_prot_p_RB1_*nuc_prot_E2F_
# Name: 324, dtype: object
# reactionId                                                  vC10
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_p_RB1__E2F_ ; nuc_prot_p_RB1_ + nuc_p...
# ratelaw                              kC10_1*nuc_prot_p_RB1__E2F_
# Name: 325, dtype: object
# reactionId                       vC11
# solver                  Deterministic
# compartment                   Nucleus
# r ; p               nuc_prot_p_RB1_ ;
# ratelaw        kC11_1*nuc_prot_p_RB1_
# Name: 326, dtype: object
# reactionId                         vC12
# solver                    Deterministic
# compartment                     Nucleus
# r ; p               nuc_prot_p_p_RB1_ ;
# ratelaw        kC12_1*nuc_prot_p_p_RB1_
# Name: 327, dtype: object
# reactionId                vC13
# solver           Deterministic
# compartment            Nucleus
# r ; p          ; nuc_prot_E2F_
# ratelaw                 kC13_1
# Name: 328, dtype: object
# reactionId                     vC16
# solver                Deterministic
# compartment                 Nucleus
# r ; p               nuc_prot_E2F_ ;
# ratelaw        kC16_1*nuc_prot_E2F_
# Name: 331, dtype: object
# reactionId                       vC17
# solver                  Deterministic
# compartment                   Nucleus
# r ; p               nuc_prot_p_E2F_ ;
# ratelaw        kC17_1*nuc_prot_p_E2F_
# Name: 332, dtype: object
# reactionId                 vC18
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_CCND_
# ratelaw                  kC18_1
# Name: 333, dtype: object
# reactionId                                        vC20
# solver                                   Deterministic
# compartment                                    Nucleus
# r ; p          nuc_prot_i_CCND__CDK4_ ; nuc_prot_CCND_
# ratelaw                  kC20_1*nuc_prot_i_CCND__CDK4_
# Name: 335, dtype: object
# reactionId                      vC22
# solver                 Deterministic
# compartment                  Nucleus
# r ; p               nuc_prot_CCND_ ;
# ratelaw        kC22_1*nuc_prot_CCND_
# Name: 337, dtype: object
# reactionId                                                  vC25
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCND__CDK4_ + nuc_prot_CDKN1B_ ; nuc_...
# ratelaw             kC25_1*nuc_prot_CCND__CDK4_*nuc_prot_CDKN1B_
# Name: 340, dtype: object
# reactionId                                                  vC26
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCND__CDK4__CDKN1B_ ; nuc_prot_CCND__...
# ratelaw                      kC26_1*nuc_prot_CCND__CDK4__CDKN1B_
# Name: 341, dtype: object
# reactionId                 vC27
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_CCNE_
# ratelaw                  kC27_1
# Name: 342, dtype: object
# reactionId                                        vC29
# solver                                   Deterministic
# compartment                                    Nucleus
# r ; p          nuc_prot_i_CCNE__CDK2_ ; nuc_prot_CCNE_
# ratelaw                  kC29_1*nuc_prot_i_CCNE__CDK2_
# Name: 344, dtype: object
# reactionId                                                  vC33
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNE__CDK2_ + nuc_prot_CDKN1B_ ; nuc_...
# ratelaw             kC33_1*nuc_prot_CCNE__CDK2_*nuc_prot_CDKN1B_
# Name: 348, dtype: object
# reactionId                                                  vC34
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNE__CDK2__CDKN1B_ ; nuc_prot_CCNE__...
# ratelaw                      kC34_1*nuc_prot_CCNE__CDK2__CDKN1B_
# Name: 349, dtype: object
# reactionId                 vC35
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_SKP2_
# ratelaw                  kC35_1
# Name: 350, dtype: object
# reactionId                      vC37
# solver                 Deterministic
# compartment                  Nucleus
# r ; p               nuc_prot_SKP2_ ;
# ratelaw        kC37_1*nuc_prot_SKP2_
# Name: 352, dtype: object
# reactionId                                 vC38
# solver                            Deterministic
# compartment                             Nucleus
# r ; p          ; nuc_prot_i_CDC25A__CCNE__CDK2_
# ratelaw                                  kC38_1
# Name: 353, dtype: object
# reactionId                                      vC41
# solver                                 Deterministic
# compartment                                  Nucleus
# r ; p               nuc_prot_i_CDC25A__CCNE__CDK2_ ;
# ratelaw        kC41_1*nuc_prot_i_CDC25A__CCNE__CDK2_
# Name: 356, dtype: object
# reactionId                                    vC42
# solver                               Deterministic
# compartment                                Nucleus
# r ; p               nuc_prot_CDC25A__CCNE__CDK2_ ;
# ratelaw        kC42_1*nuc_prot_CDC25A__CCNE__CDK2_
# Name: 357, dtype: object
# reactionId                 vC43
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_CCNA_
# ratelaw                  kC43_1
# Name: 358, dtype: object
# reactionId                                        vC45
# solver                                   Deterministic
# compartment                                    Nucleus
# r ; p          nuc_prot_i_CCNA__CDK2_ ; nuc_prot_CCNA_
# ratelaw                  kC45_1*nuc_prot_i_CCNA__CDK2_
# Name: 360, dtype: object
# reactionId                      vC47
# solver                 Deterministic
# compartment                  Nucleus
# r ; p               nuc_prot_CCNA_ ;
# ratelaw        kC47_1*nuc_prot_CCNA_
# Name: 362, dtype: object
# reactionId                                                  vC50
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNA__CDK2_ + nuc_prot_CDKN1B_ ; nuc_...
# ratelaw             kC50_1*nuc_prot_CCNA__CDK2_*nuc_prot_CDKN1B_
# Name: 365, dtype: object
# reactionId                                                  vC51
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNA__CDK2__CDKN1B_ ; nuc_prot_CCNA__...
# ratelaw                      kC51_1*nuc_prot_CCNA__CDK2__CDKN1B_
# Name: 366, dtype: object
# reactionId                          vC55
# solver                     Deterministic
# compartment                      Nucleus
# r ; p               nuc_prot_p_CDKN1B_ ;
# ratelaw        kC55_1*nuc_prot_p_CDKN1B_
# Name: 370, dtype: object
# reactionId                        vC58
# solver                   Deterministic
# compartment                    Nucleus
# r ; p               nuc_prot_i_CDH1_ ;
# ratelaw        kC58_1*nuc_prot_i_CDH1_
# Name: 373, dtype: object
# reactionId                   vC59
# solver              Deterministic
# compartment               Nucleus
# r ; p          ; nuc_prot_a_CDH1_
# ratelaw                    kC59_1
# Name: 374, dtype: object
# reactionId                        vC60
# solver                   Deterministic
# compartment                    Nucleus
# r ; p               nuc_prot_a_CDH1_ ;
# ratelaw        kC60_1*nuc_prot_a_CDH1_
# Name: 375, dtype: object
# reactionId                                 vC61
# solver                            Deterministic
# compartment                             Nucleus
# r ; p          ; nuc_prot_i_CDC25B__CCNA__CDK2_
# ratelaw                                  kC61_1
# Name: 376, dtype: object
# reactionId                                      vC64
# solver                                 Deterministic
# compartment                                  Nucleus
# r ; p               nuc_prot_i_CDC25B__CCNA__CDK2_ ;
# ratelaw        kC64_1*nuc_prot_i_CDC25B__CCNA__CDK2_
# Name: 379, dtype: object
# reactionId                                     vC65
# solver                                Deterministic
# compartment                                 Nucleus
# r ; p               nuc_prot_p_CDC25__CCNA__CDK2_ ;
# ratelaw        kC65_1*nuc_prot_p_CDC25__CCNA__CDK2_
# Name: 380, dtype: object
# reactionId                 vC66
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_CCNB_
# ratelaw                  kC66_1
# Name: 381, dtype: object
# reactionId                                        vC68
# solver                                   Deterministic
# compartment                                    Nucleus
# r ; p          nuc_prot_i_CCNB__CDK1_ ; nuc_prot_CCNB_
# ratelaw                  kC68_1*nuc_prot_i_CCNB__CDK1_
# Name: 383, dtype: object
# reactionId                      vC70
# solver                 Deterministic
# compartment                  Nucleus
# r ; p               nuc_prot_CCNB_ ;
# ratelaw        kC70_1*nuc_prot_CCNB_
# Name: 385, dtype: object
# reactionId                                                  vC73
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CDKN1B_ + nuc_prot_CCNB__CDK1_ ; nuc_...
# ratelaw             kC73_1*nuc_prot_CDKN1B_*nuc_prot_CCNB__CDK1_
# Name: 388, dtype: object
# reactionId                                                  vC74
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNB__CDK1__CDKN1B_ ; nuc_prot_CDKN1B...
# ratelaw                      kC74_1*nuc_prot_CCNB__CDK1__CDKN1B_
# Name: 389, dtype: object
# reactionId                    vC75
# solver               Deterministic
# compartment                Nucleus
# r ; p          ; nuc_prot_i_CDC20_
# ratelaw                     kC75_1
# Name: 390, dtype: object
# reactionId                         vC78
# solver                    Deterministic
# compartment                     Nucleus
# r ; p               nuc_prot_i_CDC20_ ;
# ratelaw        kC78_1*nuc_prot_i_CDC20_
# Name: 393, dtype: object
# reactionId                         vC79
# solver                    Deterministic
# compartment                     Nucleus
# r ; p               nuc_prot_a_CDC20_ ;
# ratelaw        kC79_1*nuc_prot_a_CDC20_
# Name: 394, dtype: object
# reactionId                                 vC80
# solver                            Deterministic
# compartment                             Nucleus
# r ; p          ; nuc_prot_i_CDC25C__CCNB__CDK1_
# ratelaw                                  kC80_1
# Name: 395, dtype: object
# reactionId                                      vC83
# solver                                 Deterministic
# compartment                                  Nucleus
# r ; p               nuc_prot_i_CDC25C__CCNB__CDK1_ ;
# ratelaw        kC83_1*nuc_prot_i_CDC25C__CCNB__CDK1_
# Name: 398, dtype: object
# reactionId                                   vC84
# solver                              Deterministic
# compartment                               Nucleus
# r ; p               nuc_prot_CDC25__CCNB__CDK1_ ;
# ratelaw        kC84_1*nuc_prot_CDC25__CCNB__CDK1_
# Name: 399, dtype: object
# reactionId                 vC85
# solver            Deterministic
# compartment             Nucleus
# r ; p          ; nuc_prot_WEE1_
# ratelaw                  kC85_1
# Name: 400, dtype: object
# reactionId                      vC88
# solver                 Deterministic
# compartment                  Nucleus
# r ; p               nuc_prot_WEE1_ ;
# ratelaw        kC88_1*nuc_prot_WEE1_
# Name: 403, dtype: object
# reactionId                        vC89
# solver                   Deterministic
# compartment                    Nucleus
# r ; p               nuc_prot_p_WEE1_ ;
# ratelaw        kC89_1*nuc_prot_p_WEE1_
# Name: 404, dtype: object
# reactionId                      vC92
# solver                 Deterministic
# compartment                  Nucleus
# r ; p               nuc_prot_CCNE_ ;
# ratelaw        kC92_1*nuc_prot_CCNE_
# Name: 407, dtype: object
# reactionId                   vC93
# solver              Deterministic
# compartment               Nucleus
# r ; p          ; nuc_prot_CDKN1B_
# ratelaw                    kC93_1
# Name: 408, dtype: object
# reactionId                   vC94
# solver              Deterministic
# compartment               Nucleus
# r ; p          ; nuc_prot_CDKN1B_
# ratelaw                    kC94_1
# Name: 409, dtype: object
# reactionId                        vC95
# solver                   Deterministic
# compartment                    Nucleus
# r ; p               nuc_prot_CDKN1B_ ;
# ratelaw        kC95_1*nuc_prot_CDKN1B_
# Name: 410, dtype: object
# reactionId                                                  vC96
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCND__CDK4_ + nuc_prot_CDKN1A_ ; nuc_...
# ratelaw             kC96_1*nuc_prot_CCND__CDK4_*nuc_prot_CDKN1A_
# Name: 411, dtype: object
# reactionId                                                  vC97
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCND__CDK4__CDKN1A_ ; nuc_prot_CCND__...
# ratelaw                      kC97_1*nuc_prot_CCND__CDK4__CDKN1A_
# Name: 412, dtype: object
# reactionId                                                  vC98
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNE__CDK2_ + nuc_prot_CDKN1A_ ; nuc_...
# ratelaw             kC98_1*nuc_prot_CCNE__CDK2_*nuc_prot_CDKN1A_
# Name: 413, dtype: object
# reactionId                                                  vC99
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNE__CDK2__CDKN1A_ ; nuc_prot_CCNE__...
# ratelaw                      kC99_1*nuc_prot_CCNE__CDK2__CDKN1A_
# Name: 414, dtype: object
# reactionId                                                 vC100
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNA__CDK2_ + nuc_prot_CDKN1A_ ; nuc_...
# ratelaw            kC100_1*nuc_prot_CCNA__CDK2_*nuc_prot_CDKN1A_
# Name: 415, dtype: object
# reactionId                                                 vC101
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNA__CDK2__CDKN1A_ ; nuc_prot_CCNA__...
# ratelaw                     kC101_1*nuc_prot_CCNA__CDK2__CDKN1A_
# Name: 416, dtype: object
# reactionId                                                 vC102
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNB__CDK1_ + nuc_prot_CDKN1A_ ; nuc_...
# ratelaw            kC102_1*nuc_prot_CCNB__CDK1_*nuc_prot_CDKN1A_
# Name: 417, dtype: object
# reactionId                                                 vC103
# solver                                             Deterministic
# compartment                                              Nucleus
# r ; p          nuc_prot_CCNB__CDK1__CDKN1A_ ; nuc_prot_CCNB__...
# ratelaw                     kC103_1*nuc_prot_CCNB__CDK1__CDKN1A_
# Name: 418, dtype: object
# reactionId                        vC104
# solver                    Deterministic
# compartment                     Nucleus
# r ; p                nuc_prot_CDKN1A_ ;
# ratelaw        kC104_1*nuc_prot_CDKN1A_
# Name: 419, dtype: object
# reactionId                                                   vA1
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          ext_prot_TNFSF10_ + cyt_prot_TNFRSF10_ ; cyt_p...
# ratelaw               kA1_1*ext_prot_TNFSF10_*cyt_prot_TNFRSF10_
# Name: 420, dtype: object
# reactionId                                                   vA2
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_TNFSF10__TNFRSF10_ ; ext_prot_TNFSF10...
# ratelaw                        kA2_1*cyt_prot_TNFSF10__TNFRSF10_
# Name: 421, dtype: object
# reactionId                                                   vA3
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_TNFSF10__TNFRSF10_ ; cyt_prot_a_TNFRS...
# ratelaw                        kA3_1*cyt_prot_TNFSF10__TNFRSF10_
# Name: 422, dtype: object
# reactionId                                                   vA4
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_a_TNFRSF10_ + cyt_prot_CFLAR_ ; cyt_p...
# ratelaw               kA4_1*cyt_prot_a_TNFRSF10_*cyt_prot_CFLAR_
# Name: 423, dtype: object
# reactionId                                                   vA5
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_a_TNFRSF10__CFLAR_ ; cyt_prot_a_TNFRS...
# ratelaw                        kA5_1*cyt_prot_a_TNFRSF10__CFLAR_
# Name: 424, dtype: object
# reactionId                                                   vA6
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_a_TNFRSF10_ + cyt_prot_p_CASP8_ ; cyt...
# ratelaw             kA6_1*cyt_prot_a_TNFRSF10_*cyt_prot_p_CASP8_
# Name: 425, dtype: object
# reactionId                                                   vA7
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_a_TNFRSF10__p_CASP8_ ; cyt_prot_a_TNF...
# ratelaw                      kA7_1*cyt_prot_a_TNFRSF10__p_CASP8_
# Name: 426, dtype: object
# reactionId                                                   vA8
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_a_TNFRSF10__p_CASP8_ ; cyt_prot_a_TNF...
# ratelaw                      kA8_1*cyt_prot_a_TNFRSF10__p_CASP8_
# Name: 427, dtype: object
# reactionId                                                   vA9
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_i_CASP8_ + cyt_prot_BFAR_ ; cyt_prot_...
# ratelaw                   kA9_1*cyt_prot_i_CASP8_*cyt_prot_BFAR_
# Name: 428, dtype: object
# reactionId                                                  vA10
# solver                                             Deterministic
# compartment                                            Cytoplasm
# r ; p          cyt_prot_CASP8__BFAR_ ; cyt_prot_i_CASP8_ + cy...
# ratelaw                             kA10_1*cyt_prot_CASP8__BFAR_
# Name: 429, dtype: object
# ...
# Name: 3075, dtype: object
# reactionId                          vTCd86
# solver                          Stochastic
# compartment                      Cytoplasm
# r ; p                 cyt_mrna_HRAS_201_ ;
# ratelaw        kTCd86_1*cyt_mrna_HRAS_201_
# Name: 3076, dtype: object
# reactionId                         vTCd87
# solver                         Stochastic
# compartment                     Cytoplasm
# r ; p                 cyt_mrna_NF1_202_ ;
# ratelaw        kTCd87_1*cyt_mrna_NF1_202_
# Name: 3077, dtype: object
# reactionId                          vTCd88
# solver                          Stochastic
# compartment                      Cytoplasm
# r ; p                 cyt_mrna_RAF1_201_ ;
# ratelaw        kTCd88_1*cyt_mrna_RAF1_201_
# Name: 3078, dtype: object
# reactionId                          vTCd89
# solver                          Stochastic
# compartment                      Cytoplasm
# r ; p                 cyt_mrna_BRAF_220_ ;
# ratelaw        kTCd89_1*cyt_mrna_BRAF_220_
# Name: 3079, dtype: object
# reactionId                            vTCd90
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                 cyt_mrna_MAP2K1_201_ ;
# ratelaw        kTCd90_1*cyt_mrna_MAP2K1_201_
# Name: 3080, dtype: object
# reactionId                            vTCd91
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                 cyt_mrna_MAP2K2_201_ ;
# ratelaw        kTCd91_1*cyt_mrna_MAP2K2_201_
# Name: 3081, dtype: object
# reactionId                           vTCd92
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                 cyt_mrna_DUSP6_201_ ;
# ratelaw        kTCd92_1*cyt_mrna_DUSP6_201_
# Name: 3082, dtype: object
# reactionId                             vTCd93
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                 cyt_mrna_RPS6KA1_204_ ;
# ratelaw        kTCd93_1*cyt_mrna_RPS6KA1_204_
# Name: 3083, dtype: object
# reactionId                             vTCd94
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                 cyt_mrna_RPS6KA2_201_ ;
# ratelaw        kTCd94_1*cyt_mrna_RPS6KA2_201_
# Name: 3084, dtype: object
# reactionId                             vTCd95
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                 cyt_mrna_RPS6KA3_201_ ;
# ratelaw        kTCd95_1*cyt_mrna_RPS6KA3_201_
# Name: 3085, dtype: object
# reactionId                             vTCd96
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                 cyt_mrna_RPS6KA4_201_ ;
# ratelaw        kTCd96_1*cyt_mrna_RPS6KA4_201_
# Name: 3086, dtype: object
# reactionId                           vTCd97
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                 cyt_mrna_DUSP1_201_ ;
# ratelaw        kTCd97_1*cyt_mrna_DUSP1_201_
# Name: 3087, dtype: object
# reactionId                         vTCd98
# solver                         Stochastic
# compartment                     Cytoplasm
# r ; p                 cyt_mrna_FOS_201_ ;
# ratelaw        kTCd98_1*cyt_mrna_FOS_201_
# Name: 3088, dtype: object
# reactionId                         vTCd99
# solver                         Stochastic
# compartment                     Cytoplasm
# r ; p                 cyt_mrna_JUN_201_ ;
# ratelaw        kTCd99_1*cyt_mrna_JUN_201_
# Name: 3089, dtype: object
# reactionId                         vTCd100
# solver                          Stochastic
# compartment                      Cytoplasm
# r ; p                  cyt_mrna_MYC_206_ ;
# ratelaw        kTCd100_1*cyt_mrna_MYC_206_
# Name: 3090, dtype: object
# reactionId                            vTCd101
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                  cyt_mrna_CTNNB1_201_ ;
# ratelaw        kTCd101_1*cyt_mrna_CTNNB1_201_
# Name: 3091, dtype: object
# reactionId                          vTCd102
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_PTEN_201_ ;
# ratelaw        kTCd102_1*cyt_mrna_PTEN_201_
# Name: 3092, dtype: object
# reactionId                          vTCd103
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_AKT1_218_ ;
# ratelaw        kTCd103_1*cyt_mrna_AKT1_218_
# Name: 3093, dtype: object
# reactionId                          vTCd104
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_AKT2_206_ ;
# ratelaw        kTCd104_1*cyt_mrna_AKT2_206_
# Name: 3094, dtype: object
# reactionId                           vTCd105
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PDPK1_202_ ;
# ratelaw        kTCd105_1*cyt_mrna_PDPK1_202_
# Name: 3095, dtype: object
# reactionId                            vTCd106
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                  cyt_mrna_RICTOR_202_ ;
# ratelaw        kTCd106_1*cyt_mrna_RICTOR_202_
# Name: 3096, dtype: object
# reactionId                          vTCd107
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_MTOR_201_ ;
# ratelaw        kTCd107_1*cyt_mrna_MTOR_201_
# Name: 3097, dtype: object
# reactionId                           vTCd108
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_GSK3B_201_ ;
# ratelaw        kTCd108_1*cyt_mrna_GSK3B_201_
# Name: 3098, dtype: object
# reactionId                          vTCd109
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_TSC1_201_ ;
# ratelaw        kTCd109_1*cyt_mrna_TSC1_201_
# Name: 3099, dtype: object
# reactionId                          vTCd110
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_TSC2_201_ ;
# ratelaw        kTCd110_1*cyt_mrna_TSC2_201_
# Name: 3100, dtype: object
# reactionId                           vTCd111
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PRKCA_202_ ;
# ratelaw        kTCd111_1*cyt_mrna_PRKCA_202_
# Name: 3101, dtype: object
# reactionId                           vTCd112
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PRKCB_210_ ;
# ratelaw        kTCd112_1*cyt_mrna_PRKCB_210_
# Name: 3102, dtype: object
# reactionId                           vTCd113
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PRKCG_201_ ;
# ratelaw        kTCd113_1*cyt_mrna_PRKCG_201_
# Name: 3103, dtype: object
# reactionId                           vTCd114
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PRKCD_201_ ;
# ratelaw        kTCd114_1*cyt_mrna_PRKCD_201_
# Name: 3104, dtype: object
# reactionId                           vTCd115
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PEBP1_201_ ;
# ratelaw        kTCd115_1*cyt_mrna_PEBP1_201_
# Name: 3105, dtype: object
# reactionId                           vTCd116
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_MAPK1_201_ ;
# ratelaw        kTCd116_1*cyt_mrna_MAPK1_201_
# Name: 3106, dtype: object
# reactionId                           vTCd117
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_MAPK3_201_ ;
# ratelaw        kTCd117_1*cyt_mrna_MAPK3_201_
# Name: 3107, dtype: object
# reactionId                           vTCd118
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_FOXO3_202_ ;
# ratelaw        kTCd118_1*cyt_mrna_FOXO3_202_
# Name: 3108, dtype: object
# reactionId                          vTCd119
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_RHEB_201_ ;
# ratelaw        kTCd119_1*cyt_mrna_RHEB_201_
# Name: 3109, dtype: object
# reactionId                           vTCd120
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_RPTOR_201_ ;
# ratelaw        kTCd120_1*cyt_mrna_RPTOR_201_
# Name: 3110, dtype: object
# reactionId                             vTCd121
# solver                              Stochastic
# compartment                          Cytoplasm
# r ; p                  cyt_mrna_RPS6KB1_201_ ;
# ratelaw        kTCd121_1*cyt_mrna_RPS6KB1_201_
# Name: 3111, dtype: object
# reactionId                             vTCd122
# solver                              Stochastic
# compartment                          Cytoplasm
# r ; p                  cyt_mrna_RPS6KB2_201_ ;
# ratelaw        kTCd122_1*cyt_mrna_RPS6KB2_201_
# Name: 3112, dtype: object
# reactionId                              vTCd123
# solver                               Stochastic
# compartment                           Cytoplasm
# r ; p                  cyt_mrna_EIF4EBP1_201_ ;
# ratelaw        kTCd123_1*cyt_mrna_EIF4EBP1_201_
# Name: 3113, dtype: object
# reactionId                          vTCd124
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_SOS1_202_ ;
# ratelaw        kTCd124_1*cyt_mrna_SOS1_202_
# Name: 3114, dtype: object
# reactionId                            vTCd125
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                  cyt_mrna_CDKN2A_201_ ;
# ratelaw        kTCd125_1*cyt_mrna_CDKN2A_201_
# Name: 3115, dtype: object
# reactionId                          vTCd126
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_MDM4_203_ ;
# ratelaw        kTCd126_1*cyt_mrna_MDM4_203_
# Name: 3116, dtype: object
# reactionId                           vTCd127
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_FGFR1_214_ ;
# ratelaw        kTCd127_1*cyt_mrna_FGFR1_214_
# Name: 3117, dtype: object
# reactionId                           vTCd128
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_FGFR2_206_ ;
# ratelaw        kTCd128_1*cyt_mrna_FGFR2_206_
# Name: 3118, dtype: object
# reactionId                          vTCd129
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_FGF1_201_ ;
# ratelaw        kTCd129_1*cyt_mrna_FGF1_201_
# Name: 3119, dtype: object
# reactionId                          vTCd130
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_FGF2_203_ ;
# ratelaw        kTCd130_1*cyt_mrna_FGF2_203_
# Name: 3120, dtype: object
# reactionId                           vTCd131
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_EIF4E_203_ ;
# ratelaw        kTCd131_1*cyt_mrna_EIF4E_203_
# Name: 3121, dtype: object
# reactionId                          vTCd132
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_IRS1_201_ ;
# ratelaw        kTCd132_1*cyt_mrna_IRS1_201_
# Name: 3122, dtype: object
# reactionId                          vTCd133
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_IRS2_201_ ;
# ratelaw        kTCd133_1*cyt_mrna_IRS2_201_
# Name: 3123, dtype: object
# reactionId                          vTCd134
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_IGF1_202_ ;
# ratelaw        kTCd134_1*cyt_mrna_IGF1_202_
# Name: 3124, dtype: object
# reactionId                          vTCd135
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_IGF2_205_ ;
# ratelaw        kTCd135_1*cyt_mrna_IGF2_205_
# Name: 3125, dtype: object
# reactionId                           vTCd136
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_IGF1R_217_ ;
# ratelaw        kTCd136_1*cyt_mrna_IGF1R_217_
# Name: 3126, dtype: object
# reactionId                          vTCd137
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_MSH6_201_ ;
# ratelaw        kTCd137_1*cyt_mrna_MSH6_201_
# Name: 3127, dtype: object
# reactionId                           vTCd138
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_BRCA2_201_ ;
# ratelaw        kTCd138_1*cyt_mrna_BRCA2_201_
# Name: 3128, dtype: object
# reactionId                          vTCd139
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_MGMT_205_ ;
# ratelaw        kTCd139_1*cyt_mrna_MGMT_205_
# Name: 3129, dtype: object
# reactionId                          vTCd140
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_INSR_201_ ;
# ratelaw        kTCd140_1*cyt_mrna_INSR_201_
# Name: 3130, dtype: object
# reactionId                         vTCd141
# solver                          Stochastic
# compartment                      Cytoplasm
# r ; p                  cyt_mrna_INS_202_ ;
# ratelaw        kTCd141_1*cyt_mrna_INS_202_
# Name: 3131, dtype: object
# reactionId                          vTCd142
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_IFNG_201_ ;
# ratelaw        kTCd142_1*cyt_mrna_IFNG_201_
# Name: 3132, dtype: object
# reactionId                            vTCd143
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                  cyt_mrna_IFNGR2_201_ ;
# ratelaw        kTCd143_1*cyt_mrna_IFNGR2_201_
# Name: 3133, dtype: object
# reactionId                          vTCd144
# solver                           Stochastic
# compartment                       Cytoplasm
# r ; p                  cyt_mrna_JAK1_201_ ;
# ratelaw        kTCd144_1*cyt_mrna_JAK1_201_
# Name: 3134, dtype: object
# reactionId                           vTCd145
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_STAT1_201_ ;
# ratelaw        kTCd145_1*cyt_mrna_STAT1_201_
# Name: 3135, dtype: object
# reactionId                            vTCd146
# solver                             Stochastic
# compartment                         Cytoplasm
# r ; p                  cyt_mrna_PTPN11_201_ ;
# ratelaw        kTCd146_1*cyt_mrna_PTPN11_201_
# Name: 3136, dtype: object
# reactionId                           vTCd147
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PTPN2_202_ ;
# ratelaw        kTCd147_1*cyt_mrna_PTPN2_202_
# Name: 3137, dtype: object
# reactionId                           vTCd148
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_PTPN1_201_ ;
# ratelaw        kTCd148_1*cyt_mrna_PTPN1_201_
# Name: 3138, dtype: object
# reactionId                           vTCd149
# solver                            Stochastic
# compartment                        Cytoplasm
# r ; p                  cyt_mrna_SOCS1_201_ ;
# ratelaw        kTCd149_1*cyt_mrna_SOCS1_201_
# Name: 3139, dtype: object

# %%
ratelaws_df.to_csv('../data/Ratelaws.tsv', index = False, sep = '\t')
